# %%
from groq import Groq

# %%
prompt= """
You are an intelligent Energy Optimization Decision Agent.

Your role is to analyze building energy usage and provide concise, human-friendly recommendations. Think like an experienced energy consultant.

Inputs:

* Power Category: {power_category}
* Occupancy Status: {occupancy_status}
* Temperature Category: {temperature_category}
* Time of Day: {time_of_day}

Task:
Analyze the energy usage context and determine whether the current energy consumption appears justified or potentially inefficient.

Guidelines:

* Consider the relationship between power consumption, occupancy, temperature, and time of day.
* Do not assume energy waste in every case.
* If high power consumption is justified by occupancy or environmental conditions, clearly state that.
* Keep responses concise, practical, and professional.
* Use natural language that is easy for building operators to understand.

Provide the output strictly in the following format:

Observation:
A brief summary of the situation.

Reasoning:
Explain why the situation appears normal or potentially inefficient based on the provided context.

Recommendation:
Provide a practical action or suggestion. If energy usage appears justified, mention that no immediate action is required.
"""

# %%
from groq import Groq

client=Groq(
    api_key="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"
)

# %%
response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {
            "role": "user",
            "content": prompt
        }
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# I'm ready to analyze the building energy usage context. Please provide the input parameters: Power Category, Occupancy Status, Temperature Category, and Time of Day.

# %%
prompt = """
You are an intelligent Energy Optimization Decision Agent.

Your role is to analyze building energy usage and provide concise, human-friendly recommendations. Think like an experienced energy manager explaining the situation to a building operator.

Inputs:

* Power Category: High
* Occupancy Status: Empty
* Temperature Category: Moderate
* Time of Day: Late Night

Task:
Analyze the energy usage context and determine whether the current energy consumption appears justified or potentially inefficient.

Guidelines:

* Keep the response concise and easy to read.
* Use friendly and professional language.
* Avoid technical reports and lengthy explanations.
* Observation should be 1 sentence.
* Reasoning should be 1-2 short sentences.
* Recommendation should be 1-2 short actionable sentences.
* Keep the total response under 100 words.
* Do not use bullet points.
* Do not repeat the input values.
* If energy usage appears normal, clearly state that no immediate action is required.
* If energy usage appears inefficient, suggest a practical action.

Provide the output strictly in the following format:

Observation:
A brief summary of the situation.

Reasoning:
A short explanation of why the situation appears normal or potentially inefficient.

Recommendation:
A practical and easy-to-understand suggestion.

"""

# %%
response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {"role": "user", "content": prompt}
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# Observation:
# The building is experiencing high energy consumption during a late night when it is empty, with moderate temperatures set.
#
# Reasoning:
# During late nights with empty occupancy, energy usage is generally expected to be low. However, the current high energy consumption suggests that there might be equipment or systems still operating unnecessarily.
#
# Recommendation:
# Consider reviewing and optimizing controls to shut off or reduce power to non-essential systems, such as lighting and HVAC, to minimize energy waste when the building is unoccupied. You may also consider adjusting temperature setpoints to further reduce energy consumption.
